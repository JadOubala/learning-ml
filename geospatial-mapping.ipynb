# %% [markdown]
# # Working with geospatial data
# We now turn to handling special data types, including geo-spatial data. This is a bit different than most data types we've handled.
# 1. The process of determining Latitude and Longitude from a specific human description is called "geocoding".
# 2. Geocoding is data intensive. It's not done on your computer; the databases are too large to fit.
# 3. Instead, there are Application Programming Interfaces that allow you to translate between human concepts and the more abstract concepts of Latitude and Longitude.
# 4. Most geocoding solutions are not free. You can use them as a developer with so-called "rate limiting". This allows you to submit a limited number of requests per hour for free. You would need to subscribe and pay a monthly fee to use them at high rates, e.g., to drive a web application or geocode a large repository of addresses.
# 5. Depending upon the geocoding solution, you might need an "API key" to use it. This is a string, similar to a password, that identifies you and your application uniquely and allows you to use the API within rate limits.
#
# Let's play with this concept a bit and solve some simple problems.
#
# First, note that you'll have to install geopy for this to work. In a Jupyter terminal, type
# ```
# pip install geopy
# pip install folium
# pip install polyline
# ```
# before starting these problems.
#
# Note that in this problem, running the solution directly can break folium! Thus we save the solution to an HTML file and zip it with the solution code.

# %% [markdown]
# *Question 1*: Read https://towardsdatascience.com/things-to-do-with-latitude-longitude-data-using-geopy-python-1d356ed1ae30 and then utilize geopy to calculate the latitude and longitude of Halligan Hall (161 College Avenue, Medford, MA 01801). Put these into the object `halligan`. Then read
# https://python-visualization.github.io/folium/quickstart.html and create an interactive map centered on Halligan Hall, with a marker labeled "Halligan Hall". Choose `zoom_start` reasonably to make the map depict the Tufts campus.
#
# Note: You will get the location of the pool. This is true in any geocoder. That's because there are two "161 College Avenue" addresses!

# %% [raw]
# # BEGIN SOLUTION

# %%
import folium
import geopy
# BEGIN SOLUTION
from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'lab_geo_app')

address = '161 College Avenue, Medford, MA 01801'

from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(geocoder.geocode, min_delay_seconds = 1,   return_value_on_exception = None) 
# adding 1 second padding between calls

# after initiating geocoder
location = geocode(address)
# returns location object with longitude, latitude and altitude instances
(location.latitude, location.longitude)

halligan = location

m = folium.Map(location=(halligan.latitude, halligan.longitude), zoom_start=15)
folium.Marker(
    location=[halligan.latitude, halligan.longitude],
    tooltip="Halligan Hall",
    popup="Halligan Hall",
    icon=folium.Icon(icon="cloud"),
).add_to(m)
m
# END SOLUTION
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7901b86fb55e78b6beb87804291848e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7901b86fb55e78b6beb87804291848e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7901b86fb55e78b6beb87804291848e2 = L.map(
#                 &quot;map_7901b86fb55e78b6beb87804291848e2&quot;,
#                 {
#                     center: [42.4096627, -71.1150699],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e859a9d53eed96280f62b12ff1bd4df5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e859a9d53eed96280f62b12ff1bd4df5.addTo(map_7901b86fb55e78b6beb87804291848e2);
#
#
#             var marker_314633e6f285774710150c22b3960498 = L.marker(
#                 [42.4096627, -71.1150699],
#                 {}
#             ).addTo(map_7901b86fb55e78b6beb87804291848e2);
#
#
#             var icon_12255e5d5f0815a59b1c9eef03d679d2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_314633e6f285774710150c22b3960498.setIcon(icon_12255e5d5f0815a59b1c9eef03d679d2);
#
#
#         var popup_15b387f5d0e13c1a5b1d6864beff0726 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba623aea221f67fe4f9b379deb333dce = $(`&lt;div id=&quot;html_ba623aea221f67fe4f9b379deb333dce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Halligan Hall&lt;/div&gt;`)[0];
#                 popup_15b387f5d0e13c1a5b1d6864beff0726.setContent(html_ba623aea221f67fe4f9b379deb333dce);
#
#
#
#         marker_314633e6f285774710150c22b3960498.bindPopup(popup_15b387f5d0e13c1a5b1d6864beff0726)
#         ;
#
#
#
#
#             marker_314633e6f285774710150c22b3960498.bindTooltip(
#                 `&lt;div&gt;
#                      Halligan Hall
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# *Question 2:* Read https://api-v3.mbta.com/ and then study the output of the following query to the MBTA database, which obtains the locations -- in real time -- of _every bus in the MBTA._  Use this output to plot the location of every bus in the data and label it with its vehicle number and routes.

# %%
import requests
url = 'https://api-v3.mbta.com/vehicles/'
data = requests.get(url).json()
from pprint import pprint
pprint(data)
# Out:
# {'data': [{'attributes': {'bearing': 353,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 24,
#                           'direction_id': 1,
#                           'label': '1772',
#                           'latitude': 42.328125339,
#                           'longitude': -71.08318608,
#                           'occupancy_status': 'FULL',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:54-04:00'},
#            'id': 'y1772',
#            'links': {'self': '/vehicles/y1772'},
#            'relationships': {'route': {'data': {'id': '23', 'type': 'route'}},
#                              'stop': {'data': {'id': '21151', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64462825',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 60,
#                           'carriages': [{'label': '3821',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '3642',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'}],
#                           'current_status': 'INCOMING_AT',
#                           'current_stop_sequence': 580,
#                           'direction_id': 1,
#                           'label': '3821-3642',
#                           'latitude': 42.34997,
#                           'longitude': -71.07748,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:05:26-04:00'},
#            'id': 'G-10326',
#            'links': {'self': '/vehicles/G-10326'},
#            'relationships': {'route': {'data': {'id': 'Green-C',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': '70156', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64100369',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 225,
#                           'carriages': [{'label': '3824',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '3600',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'}],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 610,
#                           'direction_id': 0,
#                           'label': '3824-3600',
#                           'latitude': 42.33791,
#                           'longitude': -71.09507,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': 6.0,
#                           'updated_at': '2024-10-28T14:06:37-04:00'},
#            'id': 'G-10279',
#            'links': {'self': '/vehicles/G-10279'},
#            'relationships': {'route': {'data': {'id': 'Green-E',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': '70245', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64100768',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 326,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 12,
#                           'direction_id': 1,
#                           'label': '1847',
#                           'latitude': 42.322888419,
#                           'longitude': -71.07307756,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:55-04:00'},
#            'id': 'y1847',
#            'links': {'self': '/vehicles/y1847'},
#            'relationships': {'route': {'data': {'id': '15', 'type': 'route'}},
#                              'stop': {'data': {'id': '1485', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64464091-OL1',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 5,
#                           'carriages': [{'label': '1410',
#                                          'occupancy_percentage': 13,
#                                          'occupancy_status': 'FEW_SEATS_AVAILABLE'},
#                                         {'label': '1411',
#                                          'occupancy_percentage': 27,
#                                          'occupancy_status': 'STANDING_ROOM_ONLY'},
#                                         {'label': '1454',
#                                          'occupancy_percentage': 8,
#                                          'occupancy_status': 'FEW_SEATS_AVAILABLE'},
#                                         {'label': '1455',
#                                          'occupancy_percentage': 22,
#                                          'occupancy_status': 'STANDING_ROOM_ONLY'},
#                                         {'label': '1409',
#                                          'occupancy_percentage': 13,
#                                          'occupancy_status': 'FEW_SEATS_AVAILABLE'},
#                                         {'label': '1408',
#                                          'occupancy_percentage': 7,
#                                          'occupancy_status': 'MANY_SEATS_AVAILABLE'}],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 90,
#                           'direction_id': 1,
#                           'label': '1410',
#                           'latitude': 42.35235,
#                           'longitude': -71.06259,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:47-04:00'},
#            'id': 'O-547F6551',
#            'links': {'self': '/vehicles/O-547F6551'},
#            'relationships': {'route': {'data': {'id': 'Orange',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': '70019', 'type': 'stop'}},
#                              'trip': {'data': {'id': 'ADDED-1582114613',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 207,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 70,
#                           'direction_id': 0,
#                           'label': '1856',
#                           'latitude': 41.94293212890625,
#                           'longitude': -71.28347778320312,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': 13.4,
#                           'updated_at': '2024-10-28T14:06:20-04:00'},
#            'id': '1856',
#            'links': {'self': '/vehicles/1856'},
#            'relationships': {'route': {'data': {'id': 'CR-Providence',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': 'NEC-1969-03',
#                                                'type': 'stop'}},
#                              'trip': {'data': {'id': 'CR-670275-817',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 345,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': None,
#                           'direction_id': None,
#                           'label': '225',
#                           'latitude': 41.64717548,
#                           'longitude': -72.67554869,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:04:30-04:00'},
#            'id': 'ynk225',
#            'links': {'self': '/vehicles/ynk225'},
#            'relationships': {'route': {'data': {'id': 'Shuttle-Generic',
#                                                 'type': 'route'}},
#                              'stop': {'data': None},
#                              'trip': {'data': {'id': 'BL-3517646',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 27,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 24,
#                           'direction_id': 0,
#                           'label': '2070',
#                           'latitude': 42.42689814,
#                           'longitude': -71.06686103,
#                           'occupancy_status': 'FEW_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:32-04:00'},
#            'id': 'y2070',
#            'links': {'self': '/vehicles/y2070'},
#            'relationships': {'route': {'data': {'id': '104', 'type': 'route'}},
#                              'stop': {'data': {'id': '9215', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64899552',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 135,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 1,
#                           'label': '3308',
#                           'latitude': 42.45578,
#                           'longitude': -70.97359,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:02-04:00'},
#            'id': 'y3308',
#            'links': {'self': '/vehicles/y3308'},
#            'relationships': {'route': {'data': {'id': '429', 'type': 'route'}},
#                              'stop': {'data': {'id': '56732', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65138902',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 270,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 49,
#                           'direction_id': 1,
#                           'label': '3355',
#                           'latitude': 42.4644,
#                           'longitude': -70.93441,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:50-04:00'},
#            'id': 'y3355',
#            'links': {'self': '/vehicles/y3355'},
#            'relationships': {'route': {'data': {'id': '442', 'type': 'route'}},
#                              'stop': {'data': {'id': '4892', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65139048',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 0,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 0,
#                           'label': '2115',
#                           'latitude': 42.37359425,
#                           'longitude': -71.1193586,
#                           'occupancy_status': 'FEW_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:56-04:00'},
#            'id': 'y2115',
#            'links': {'self': '/vehicles/y2115'},
#            'relationships': {'route': {'data': {'id': '73', 'type': 'route'}},
#                              'stop': {'data': {'id': '76123', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64820055',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 315,
#                           'carriages': [{'label': '3620',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '3864',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'}],
#                           'current_status': 'INCOMING_AT',
#                           'current_stop_sequence': 450,
#                           'direction_id': 1,
#                           'label': '3620-3864',
#                           'latitude': 42.32912,
#                           'longitude': -71.11077,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': 5.1,
#                           'updated_at': '2024-10-28T14:06:52-04:00'},
#            'id': 'G-10005',
#            'links': {'self': '/vehicles/G-10005'},
#            'relationships': {'route': {'data': {'id': 'Green-E',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': '70258', 'type': 'stop'}},
#                              'trip': {'data': {'id': 'ADDED-1582114663',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 90,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 1,
#                           'label': '3103',
#                           'latitude': 42.41243,
#                           'longitude': -70.99147,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:11-04:00'},
#            'id': 'y3103',
#            'links': {'self': '/vehicles/y3103'},
#            'relationships': {'route': {'data': {'id': '117', 'type': 'route'}},
#                              'stop': {'data': {'id': '15795', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65139380',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 115,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 8,
#                           'direction_id': 0,
#                           'label': '0758',
#                           'latitude': 42.24903269,
#                           'longitude': -70.986571729,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:55-04:00'},
#            'id': 'y0758',
#            'links': {'self': '/vehicles/y0758'},
#            'relationships': {'route': {'data': {'id': '222', 'type': 'route'}},
#                              'stop': {'data': {'id': '3523', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65025280',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 39,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': None,
#                           'direction_id': None,
#                           'label': '322',
#                           'latitude': 42.338718559,
#                           'longitude': -71.04399623,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:02:04-04:00'},
#            'id': 'ynk322',
#            'links': {'self': '/vehicles/ynk322'},
#            'relationships': {'route': {'data': {'id': 'Shuttle-Generic',
#                                                 'type': 'route'}},
#                              'stop': {'data': None},
#                              'trip': {'data': {'id': 'BL-35772253',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 0,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 1,
#                           'label': '1704',
#                           'latitude': 42.23728338,
#                           'longitude': -71.132256949,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:55-04:00'},
#            'id': 'y1704',
#            'links': {'self': '/vehicles/y1704'},
#            'relationships': {'route': {'data': {'id': '32', 'type': 'route'}},
#                              'stop': {'data': {'id': '42819', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65050443',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 94,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 20,
#                           'direction_id': 0,
#                           'label': '1786',
#                           'latitude': 42.3356947,
#                           'longitude': -71.031277919,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:51-04:00'},
#            'id': 'y1786',
#            'links': {'self': '/vehicles/y1786'},
#            'relationships': {'route': {'data': {'id': '9', 'type': 'route'}},
#                              'stop': {'data': {'id': '27', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64463064',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 90,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 1,
#                           'label': '1886',
#                           'latitude': 42.33868,
#                           'longitude': -71.03179,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:50-04:00'},
#            'id': 'y1886',
#            'links': {'self': '/vehicles/y1886'},
#            'relationships': {'route': {'data': {'id': '11', 'type': 'route'}},
#                              'stop': {'data': {'id': '33', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64463211',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 95,
#                           'carriages': [{'label': '1876',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1877',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1834',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1835',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1818',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1819',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'}],
#                           'current_status': 'INCOMING_AT',
#                           'current_stop_sequence': 10,
#                           'direction_id': 0,
#                           'label': '1876',
#                           'latitude': 42.39774,
#                           'longitude': -71.13272,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:40-04:00'},
#            'id': 'R-547F6EB5',
#            'links': {'self': '/vehicles/R-547F6EB5'},
#            'relationships': {'route': {'data': {'id': 'Red', 'type': 'route'}},
#                              'stop': {'data': {'id': '70063', 'type': 'stop'}},
#                              'trip': {'data': {'id': '63919696',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 211,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': None,
#                           'direction_id': None,
#                           'label': '257',
#                           'latitude': 42.3880813,
#                           'longitude': -71.02412286,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:05:30-04:00'},
#            'id': 'ynk257',
#            'links': {'self': '/vehicles/ynk257'},
#            'relationships': {'route': {'data': {'id': 'Shuttle-Generic',
#                                                 'type': 'route'}},
#                              'stop': {'data': None},
#                              'trip': {'data': {'id': 'BL-47474943',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 294,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 2,
#                           'direction_id': 1,
#                           'label': '3239',
#                           'latitude': 42.3816379,
#                           'longitude': -71.08435898,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:52-04:00'},
#            'id': 'y3239',
#            'links': {'self': '/vehicles/y3239'},
#            'relationships': {'route': {'data': {'id': '747', 'type': 'route'}},
#                              'stop': {'data': {'id': '12759', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64460527',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 331,
#                           'carriages': [{'label': '3842',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '3645',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'}],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 710,
#                           'direction_id': 1,
#                           'label': '3842-3645',
#                           'latitude': 42.40839,
#                           'longitude': -71.1173,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': 4.6,
#                           'updated_at': '2024-10-28T14:03:21-04:00'},
#            'id': 'G-10320',
#            'links': {'self': '/vehicles/G-10320'},
#            'relationships': {'route': {'data': {'id': 'Green-E',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': '70511', 'type': 'stop'}},
#                              'trip': {'data': {'id': 'ADDED-1582114668',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 180,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 21,
#                           'direction_id': 0,
#                           'label': '1794',
#                           'latitude': 42.302114739,
#                           'longitude': -71.05969319,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:54-04:00'},
#            'id': 'y1794',
#            'links': {'self': '/vehicles/y1794'},
#            'relationships': {'route': {'data': {'id': '18', 'type': 'route'}},
#                              'stop': {'data': {'id': '320', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64465622',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 95,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 3,
#                           'direction_id': 1,
#                           'label': '2095',
#                           'latitude': 42.37539695,
#                           'longitude': -71.11431807,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:53-04:00'},
#            'id': 'y2095',
#            'links': {'self': '/vehicles/y2095'},
#            'relationships': {'route': {'data': {'id': '69', 'type': 'route'}},
#                              'stop': {'data': {'id': '1400', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64820400',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 270,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 0,
#                           'label': '1624',
#                           'latitude': 42.30278,
#                           'longitude': -71.11042,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:05:55-04:00'},
#            'id': 'y1624',
#            'links': {'self': '/vehicles/y1624'},
#            'relationships': {'route': {'data': {'id': '35', 'type': 'route'}},
#                              'stop': {'data': {'id': '10642', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65049404',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 149,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 25,
#                           'direction_id': 0,
#                           'label': '0762',
#                           'latitude': 42.22031341,
#                           'longitude': -70.96903088,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:55-04:00'},
#            'id': 'y0762',
#            'links': {'self': '/vehicles/y0762'},
#            'relationships': {'route': {'data': {'id': '225', 'type': 'route'}},
#                              'stop': {'data': {'id': '3806', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65025317',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 276,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 1,
#                           'label': '2096',
#                           'latitude': 42.41522555,
#                           'longitude': -71.032471779,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:50-04:00'},
#            'id': 'y2096',
#            'links': {'self': '/vehicles/y2096'},
#            'relationships': {'route': {'data': {'id': '111', 'type': 'route'}},
#                              'stop': {'data': {'id': '5547', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64898740',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 306,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 4,
#                           'direction_id': 0,
#                           'label': '1315',
#                           'latitude': 42.34764771,
#                           'longitude': -71.040947929,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:49-04:00'},
#            'id': 'y1315',
#            'links': {'self': '/vehicles/y1315'},
#            'relationships': {'route': {'data': {'id': '741', 'type': 'route'}},
#                              'stop': {'data': {'id': '74624', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65136485',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 113,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': None,
#                           'direction_id': None,
#                           'label': '232',
#                           'latitude': 42.39743233,
#                           'longitude': -71.0837899,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:58-04:00'},
#            'id': 'ynk232',
#            'links': {'self': '/vehicles/ynk232'},
#            'relationships': {'route': {'data': {'id': 'Shuttle-Generic',
#                                                 'type': 'route'}},
#                              'stop': {'data': None},
#                              'trip': {'data': {'id': 'BL-81250482',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': None,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 100,
#                           'direction_id': 1,
#                           'label': '1723',
#                           'latitude': 42.3765754699707,
#                           'longitude': -71.07495880126953,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:29-04:00'},
#            'id': '1723',
#            'links': {'self': '/vehicles/1723'},
#            'relationships': {'route': {'data': {'id': 'CR-Newburyport',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': 'BNT-0000',
#                                                'type': 'stop'}},
#                              'trip': {'data': {'id': 'BradfordSwap691694-154',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 268,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 8,
#                           'direction_id': 0,
#                           'label': '1748',
#                           'latitude': 42.35766741,
#                           'longitude': -71.16457824,
#                           'occupancy_status': 'FEW_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:52-04:00'},
#            'id': 'y1748',
#            'links': {'self': '/vehicles/y1748'},
#            'relationships': {'route': {'data': {'id': '504', 'type': 'route'}},
#                              'stop': {'data': {'id': '903', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64465008',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 66,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 0,
#                           'label': '1655',
#                           'latitude': 42.26761797,
#                           'longitude': -71.09274474,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:19-04:00'},
#            'id': 'y1655',
#            'links': {'self': '/vehicles/y1655'},
#            'relationships': {'route': {'data': {'id': '33', 'type': 'route'}},
#                              'stop': {'data': {'id': '185', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65050276',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 180,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 2,
#                           'direction_id': 0,
#                           'label': '0799',
#                           'latitude': 42.2819522,
#                           'longitude': -71.0654393,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:51-04:00'},
#            'id': 'y0799',
#            'links': {'self': '/vehicles/y0799'},
#            'relationships': {'route': {'data': {'id': '240', 'type': 'route'}},
#                              'stop': {'data': {'id': '536', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65025586',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 204,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 2,
#                           'direction_id': 0,
#                           'label': '1677',
#                           'latitude': 42.29930743,
#                           'longitude': -71.11394525,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:54-04:00'},
#            'id': 'y1677',
#            'links': {'self': '/vehicles/y1677'},
#            'relationships': {'route': {'data': {'id': '32', 'type': 'route'}},
#                              'stop': {'data': {'id': '6495', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65050615',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': None,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 40,
#                           'direction_id': 0,
#                           'label': '1812',
#                           'latitude': 42.47365951538086,
#                           'longitude': -70.92274475097656,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:09-04:00'},
#            'id': '1812',
#            'links': {'self': '/vehicles/1812'},
#            'relationships': {'route': {'data': {'id': 'CR-Newburyport',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': 'ER-0128-01',
#                                                'type': 'stop'}},
#                              'trip': {'data': {'id': 'BradfordSwap691670-111',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 110,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 41,
#                           'direction_id': 0,
#                           'label': '3309',
#                           'latitude': 42.45692705,
#                           'longitude': -71.02231795,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:52-04:00'},
#            'id': 'y3309',
#            'links': {'self': '/vehicles/y3309'},
#            'relationships': {'route': {'data': {'id': '429', 'type': 'route'}},
#                              'stop': {'data': {'id': '7559', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65138895',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 0,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 11,
#                           'direction_id': 1,
#                           'label': '1277',
#                           'latitude': 42.35203304,
#                           'longitude': -71.06280058,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:45-04:00'},
#            'id': 'y1277',
#            'links': {'self': '/vehicles/y1277'},
#            'relationships': {'route': {'data': {'id': '751', 'type': 'route'}},
#                              'stop': {'data': {'id': '6537', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65137010',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 122,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 6,
#                           'direction_id': 1,
#                           'label': '1924',
#                           'latitude': 42.33218767,
#                           'longitude': -71.07966216,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:52-04:00'},
#            'id': 'y1924',
#            'links': {'self': '/vehicles/y1924'},
#            'relationships': {'route': {'data': {'id': '708', 'type': 'route'}},
#                              'stop': {'data': {'id': '15088', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64462985',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 151,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 5,
#                           'direction_id': 1,
#                           'label': '1319',
#                           'latitude': 42.373175449,
#                           'longitude': -71.0298018,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:56-04:00'},
#            'id': 'y1319',
#            'links': {'self': '/vehicles/y1319'},
#            'relationships': {'route': {'data': {'id': '743', 'type': 'route'}},
#                              'stop': {'data': {'id': '7097', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65137753',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 0,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': None,
#                           'direction_id': None,
#                           'label': '317',
#                           'latitude': 42.33871886,
#                           'longitude': -71.04378053,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T13:40:12-04:00'},
#            'id': 'ynk317',
#            'links': {'self': '/vehicles/ynk317'},
#            'relationships': {'route': {'data': {'id': 'Shuttle-Generic',
#                                                 'type': 'route'}},
#                              'stop': {'data': None},
#                              'trip': {'data': {'id': 'BL-124563184',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 208,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 1,
#                           'label': '1292',
#                           'latitude': 42.32981232,
#                           'longitude': -71.08405417,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:52-04:00'},
#            'id': 'y1292',
#            'links': {'self': '/vehicles/y1292'},
#            'relationships': {'route': {'data': {'id': '749', 'type': 'route'}},
#                              'stop': {'data': {'id': '64', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65137301',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 109,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 21,
#                           'direction_id': 0,
#                           'label': '1800',
#                           'latitude': 42.29291218,
#                           'longitude': -71.08099496,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:54-04:00'},
#            'id': 'y1800',
#            'links': {'self': '/vehicles/y1800'},
#            'relationships': {'route': {'data': {'id': '22', 'type': 'route'}},
#                              'stop': {'data': {'id': '422', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64464259',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 22,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 8,
#                           'direction_id': 0,
#                           'label': '2067',
#                           'latitude': 42.34849894,
#                           'longitude': -71.153731089,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:52-04:00'},
#            'id': 'y2067',
#            'links': {'self': '/vehicles/y2067'},
#            'relationships': {'route': {'data': {'id': '86', 'type': 'route'}},
# ...
#                           'updated_at': '2024-10-28T14:06:54-04:00'},
#            'id': 'y1889',
#            'links': {'self': '/vehicles/y1889'},
#            'relationships': {'route': {'data': {'id': '16', 'type': 'route'}},
#                              'stop': {'data': {'id': '12932', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64463564',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 0,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 1,
#                           'label': '3247',
#                           'latitude': 42.37632216,
#                           'longitude': -71.11932037,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:34-04:00'},
#            'id': 'y3247',
#            'links': {'self': '/vehicles/y3247'},
#            'relationships': {'route': {'data': {'id': '66', 'type': 'route'}},
#                              'stop': {'data': {'id': '22549', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64459474',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 33,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 0,
#                           'label': '1653',
#                           'latitude': 42.335620519,
#                           'longitude': -71.09961271,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:57-04:00'},
#            'id': 'y1653',
#            'links': {'self': '/vehicles/y1653'},
#            'relationships': {'route': {'data': {'id': '39', 'type': 'route'}},
#                              'stop': {'data': {'id': '11780', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65050062_1',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 195,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': None,
#                           'direction_id': None,
#                           'label': '313',
#                           'latitude': 42.41405683,
#                           'longitude': -71.076463149,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:54-04:00'},
#            'id': 'ynk313',
#            'links': {'self': '/vehicles/ynk313'},
#            'relationships': {'route': {'data': {'id': 'Shuttle-Generic',
#                                                 'type': 'route'}},
#                              'stop': {'data': None},
#                              'trip': {'data': {'id': 'BL-60596180',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 24,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 10,
#                           'direction_id': 1,
#                           'label': '1221',
#                           'latitude': 42.28594919,
#                           'longitude': -71.09073978,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:50-04:00'},
#            'id': 'y1221',
#            'links': {'self': '/vehicles/y1221'},
#            'relationships': {'route': {'data': {'id': '28', 'type': 'route'}},
#                              'stop': {'data': {'id': '1732', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65136794',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 0,
#                           'carriages': [{'label': '1622',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1623',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1607',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1606',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '1517',
#                                          'occupancy_percentage': 3,
#                                          'occupancy_status': 'MANY_SEATS_AVAILABLE'},
#                                         {'label': '1516',
#                                          'occupancy_percentage': 8,
#                                          'occupancy_status': 'FEW_SEATS_AVAILABLE'}],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 110,
#                           'direction_id': 1,
#                           'label': '1622',
#                           'latitude': 42.33022,
#                           'longitude': -71.05697,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:56-04:00'},
#            'id': 'R-547F64AF',
#            'links': {'self': '/vehicles/R-547F64AF'},
#            'relationships': {'route': {'data': {'id': 'Red', 'type': 'route'}},
#                              'stop': {'data': {'id': '70084', 'type': 'stop'}},
#                              'trip': {'data': {'id': '63919817',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 20,
#                           'carriages': [{'label': '3827',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'}],
#                           'current_status': 'INCOMING_AT',
#                           'current_stop_sequence': 600,
#                           'direction_id': 1,
#                           'label': '3827',
#                           'latitude': 42.35301,
#                           'longitude': -71.06454,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:05:14-04:00'},
#            'id': 'G-10212',
#            'links': {'self': '/vehicles/G-10212'},
#            'relationships': {'route': {'data': {'id': 'Green-D',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': '71199', 'type': 'stop'}},
#                              'trip': {'data': {'id': 'ADDED-1582114636',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 187,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': None,
#                           'direction_id': None,
#                           'label': '331',
#                           'latitude': 42.427212349,
#                           'longitude': -71.07349557,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:58-04:00'},
#            'id': 'ynk331',
#            'links': {'self': '/vehicles/ynk331'},
#            'relationships': {'route': {'data': {'id': 'Shuttle-Generic',
#                                                 'type': 'route'}},
#                              'stop': {'data': None},
#                              'trip': {'data': {'id': 'BL-1798432',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 225,
#                           'carriages': [{'label': '3640',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '3880',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'}],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 450,
#                           'direction_id': 0,
#                           'label': '3640-3880',
#                           'latitude': 42.34523,
#                           'longitude': -71.10461,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': 4.0,
#                           'updated_at': '2024-10-28T14:06:12-04:00'},
#            'id': 'G-10278',
#            'links': {'self': '/vehicles/G-10278'},
#            'relationships': {'route': {'data': {'id': 'Green-D',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': '70187', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64101022',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 290,
#                           'carriages': [],
#                           'current_status': 'IN_TRANSIT_TO',
#                           'current_stop_sequence': 8,
#                           'direction_id': 1,
#                           'label': '1313',
#                           'latitude': 42.34778426,
#                           'longitude': -71.041486539,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:54-04:00'},
#            'id': 'y1313',
#            'links': {'self': '/vehicles/y1313'},
#            'relationships': {'route': {'data': {'id': '742', 'type': 'route'}},
#                              'stop': {'data': {'id': '74615', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65137929',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 125,
#                           'carriages': [{'label': '3840',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'},
#                                         {'label': '3603',
#                                          'occupancy_percentage': None,
#                                          'occupancy_status': 'NO_DATA_AVAILABLE'}],
#                           'current_status': 'INCOMING_AT',
#                           'current_stop_sequence': 10,
#                           'direction_id': 0,
#                           'label': '3840-3603',
#                           'latitude': 42.36689,
#                           'longitude': -71.06814,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': 9.1,
#                           'updated_at': '2024-10-28T14:06:55-04:00'},
#            'id': 'G-10263',
#            'links': {'self': '/vehicles/G-10263'},
#            'relationships': {'route': {'data': {'id': 'Green-E',
#                                                 'type': 'route'}},
#                              'stop': {'data': {'id': '70208', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64100502',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 319,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 22,
#                           'direction_id': 0,
#                           'label': '3317',
#                           'latitude': 42.42546961,
#                           'longitude': -71.01982511,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:56-04:00'},
#            'id': 'y3317',
#            'links': {'self': '/vehicles/y3317'},
#            'relationships': {'route': {'data': {'id': '119', 'type': 'route'}},
#                              'stop': {'data': {'id': '6258', 'type': 'stop'}},
#                              'trip': {'data': {'id': '65138690',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 27,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 2,
#                           'direction_id': 0,
#                           'label': '3240',
#                           'latitude': 42.33087748,
#                           'longitude': -71.08281135,
#                           'occupancy_status': None,
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:53-04:00'},
#            'id': 'y3240',
#            'links': {'self': '/vehicles/y3240'},
#            'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#                              'stop': {'data': {'id': '1', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64459169',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'},
#           {'attributes': {'bearing': 318,
#                           'carriages': [],
#                           'current_status': 'STOPPED_AT',
#                           'current_stop_sequence': 1,
#                           'direction_id': 1,
#                           'label': '1415',
#                           'latitude': 42.38676076,
#                           'longitude': -71.07731339,
#                           'occupancy_status': 'MANY_SEATS_AVAILABLE',
#                           'revenue': 'REVENUE',
#                           'speed': None,
#                           'updated_at': '2024-10-28T14:06:50-04:00'},
#            'id': 'y1415',
#            'links': {'self': '/vehicles/y1415'},
#            'relationships': {'route': {'data': {'id': '134', 'type': 'route'}},
#                              'stop': {'data': {'id': '9147', 'type': 'stop'}},
#                              'trip': {'data': {'id': '64907233',
#                                                'type': 'trip'}}},
#            'type': 'vehicle'}],
#  'jsonapi': {'version': '1.0'}}

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
import folium
import requests

# Centered in Boston
m = folium.Map(location=[42.3601, -71.0589], zoom_start=12)

for bus in data['data']:
    attributes = bus['attributes']
    
    # Extract latitude, longitude, vehicle label, and route ID
    latitude = attributes['latitude']
    longitude = attributes['longitude']
    vehicle_label = attributes['label']
    route_id = bus['relationships']['route']['data']['id'] if 'route' in bus['relationships'] else 'N/A'
    
    # Create popup text with vehicle and route info
    popup_text = f"Vehicle: {vehicle_label}<br>Route: {route_id}"
    
    # Add a marker for each bus
    folium.Marker(
        [latitude, longitude],
        popup=popup_text,
        tooltip=vehicle_label,  # Shows vehicle label on hover
        icon=folium.Icon(color="blue", icon="bus", prefix="fa")
    ).add_to(m)

m
# END SOLUTION
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b64943a8c7ec7b452d0248f06d9d350e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b64943a8c7ec7b452d0248f06d9d350e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b64943a8c7ec7b452d0248f06d9d350e = L.map(
#                 &quot;map_b64943a8c7ec7b452d0248f06d9d350e&quot;,
#                 {
#                     center: [42.3601, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b9ddae3472f895049a0763f920e1fbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1b9ddae3472f895049a0763f920e1fbc.addTo(map_b64943a8c7ec7b452d0248f06d9d350e);
#
#
#             var marker_32c5d69f673567f288b79322b2c1b5b6 = L.marker(
#                 [42.328125339, -71.08318608],
#                 {}
#             ).addTo(map_b64943a8c7ec7b452d0248f06d9d350e);
#
#
#             var icon_96a896c8551175850dbe608d2ec175a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_32c5d69f673567f288b79322b2c1b5b6.setIcon(icon_96a896c8551175850dbe608d2ec175a8);
#
#
#         var popup_ee0520c2101f1df75c91a6bdf1fdcb76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f38f4f9e0c4e8a6f79442cddecf22ee1 = $(`&lt;div id=&quot;html_f38f4f9e0c4e8a6f79442cddecf22ee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle: 1772&lt;br&gt;Route: 23&lt;/div&gt;`)[0];
#                 popup_ee0520c2101f1df75c91a6bdf1fdcb76.setContent(html_f38f4f9e0c4e8a6f79442cddecf22ee1);
#
#
#
#         marker_32c5d69f673567f288b79322b2c1b5b6.bindPopup(popup_ee0520c2101f1df75c91a6bdf1fdcb76)
#         ;
#
#
#
#
#             marker_32c5d69f673567f288b79322b2c1b5b6.bindTooltip(
#                 `&lt;div&gt;
#                      1772
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2862e6b6625981bbf25cb6b92e21282a = L.marker(
#                 [42.34997, -71.07748],
#                 {}
#             ).addTo(map_b64943a8c7ec7b452d0248f06d9d350e);
#
#
#             var icon_c93db4a7f0411c655914d64c3c29d830 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2862e6b6625981bbf25cb6b92e21282a.setIcon(icon_c93db4a7f0411c655914d64c3c29d830);
#
#
#         var popup_21585e61bac900e463d5ef437ed67091 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_724b67aa6ec088fef23b3ddf721d0e20 = $(`&lt;div id=&quot;html_724b67aa6ec088fef23b3ddf721d0e20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle: 3821-3642&lt;br&gt;Route: Green-C&lt;/div&gt;`)[0];
#                 popup_21585e61bac900e463d5ef437ed67091.setContent(html_724b67aa6ec088fef23b3ddf721d0e20);
#
#
#
#         marker_2862e6b6625981bbf25cb6b92e21282a.bindPopup(popup_21585e61bac900e463d5ef437ed67091)
#         ;
#
#
#
#
#             marker_2862e6b6625981bbf25cb6b92e21282a.bindTooltip(
#                 `&lt;div&gt;
#                      3821-3642
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3d437439a5402b32d51ea1b0db92983e = L.marker(
#                 [42.33791, -71.09507],
#                 {}
#             ).addTo(map_b64943a8c7ec7b452d0248f06d9d350e);
#
#
#             var icon_68bcf47b5a755338a700c3dec5da2a98 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3d437439a5402b32d51ea1b0db92983e.setIcon(icon_68bcf47b5a755338a700c3dec5da2a98);
#
#
#         var popup_69db0feccf85751983b0ac54101526cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b120001afb8557e909c310823db971cc = $(`&lt;div id=&quot;html_b120001afb8557e909c310823db971cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle: 3824-3600&lt;br&gt;Route: Green-E&lt;/div&gt;`)[0];
#                 popup_69db0feccf85751983b0ac54101526cb.setContent(html_b120001afb8557e909c310823db971cc);
#
#
#
#         marker_3d437439a5402b32d51ea1b0db92983e.bindPopup(popup_69db0f

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# *Question 3:* Study the output of the query below and then visualize the route of bus route 96 on a folium map. This requires converting the routes to shapes that folium can understand.
#
# *Hint:* the shapes are encoded and you'll need the google-based polyline format decoder described here: https://polyline.readthedocs.io/en/v1.1/ Use the instructions for *decoding.*

# %%
# the documentation is rather opaque on how to do this: 
url = 'https://api-v3.mbta.com/shapes?filter[route]=96'
shapes = requests.get(url).json()
pprint(shapes)
# Out:
# {'data': [{'attributes': {'polyline': 'eesaGdmaqL]K_@Gk@Ck@A[?]BU?sAHg@DWDODKJMPM\\KNEQAOU`@c@`@EBC@[PeCn@g@HM@??[@cBG_BKmBIq@Eq@GyAGoAGcDQ??OAiDQoFYcCO_AEM?OA??yAIyAIeBK}AK_ACy@FiAPu@N??YFa@FSDaARw@\\UL[T??WT_B`Bm@r@e@n@eCgEs@iA_AaBSR[X??MJ{AtAwAnAIH}@j@eB|@??_@Rs@u@m@k@WY{@}@eBiB{ApEgAk@??c@Uo@jDI|AQrA??Kt@eAg@_@Q_Ae@uAs@g@WYOY]Yc@Q_@Sa@cAaDQk@??Oc@i@wAwAiCoCiE????{@kAGm@W_@OIOAEBEFCHCH[^YZ]B??}@HiCN_Gf@gDVeAJ??m@Di@Fc@CA?aAc@cBkAKE??OICAe@Ga@H{A`AqA|@iAz@}@v@MJ??s@p@y@|@{@bAsBpCeAjBeArBgArBg@x@??KPwA{@UM}@g@_@WqAq@UM??qAw@{BqA_@ULe@??h@sBTk@dBeGf@iBt@aC??HS~@yCVeApAaEl@qB??FOBq@Cs@OgDS{CW{C??AW{@J}@F_ABw@?e@?a@Ag@C??OAyBMs@Ck@?K[IQEMOHa@JSDM?}@???oCAU?}@Kk@KSGwAu@e@]WSIMEOASb@_CRiA??RgAn@uCRaA`DjBp@aCBu@C[EUYe@??wAqA{@|CuAM'},
#            'id': '960145',
#            'links': {'self': '/shapes/960145'},
#            'type': 'shape'},
#           {'attributes': {'polyline': 'su{aG|~~pLc@EgCI@vBFvC??@V?j@PhBLlBXzAZ`@RRPJ??TLpAt@r@R`@Jn@FL@~@@hCA??P?jBBj@?r@BxBLd@B??P@`@@d@?v@?~@C|@Gz@KDf@??RjCRzCNfDBr@Ch@???Fu@`CqA`EWdA_AxCM`@??q@rBg@hBeBdGUj@m@`C??IV^TzBpAxAz@??LHpAp@^V|@f@TLvAz@T]??\\m@fAsBdAsBdAkBrBqCz@cAr@y@??DC`A}@|@w@hA{@pA}@zAaA`@Id@FB@ZNv@j@??j@^`Ab@@?b@BNC??XCrBQfDW~Fg@hCOhAK??PAXB\\FV\\^FN[HWz@jALR??`CtDvAhCh@vA`@nAPf@??p@xBR`@P^Xb@X\\XNf@VtAr@~@d@^Pl@X??VLb@Zt@N^U^SpB}@h@_@??lAw@^S~@e@vAq@XO??jBaA|@k@HIvAoAzAuAh@e@DE??LM~@`Br@hAdCfELTHOf@u@DG@A??r@u@t@w@JIf@]\\Ur@YLEf@MPE\\I??RC`AQ|AYXCf@?h@Br@DfAD|BPd@@jBJ|@D??rCLtAH~BN`BF|@F`@BR@??hAFvAJ^BhCHbAHbCLxBNjAD`@A??VAfD}@pAa@f@QEGMSJOL]LQJKNEVEf@ErAIT?\\CZ?j@@j@B^FJB??^Jf@R`@b@P`@Hd@H|@F|@Fz@Bj@Ap@Dr@B|@Nr@PZRVPw@ZaBf@Z\\R'},
#            'id': '960144',
#            'links': {'self': '/shapes/960144'},
#            'type': 'shape'}],
#  'jsonapi': {'version': '1.0'}}

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
from polyline.codec import PolylineCodec

m = folium.Map(location=[42.3601, -71.0589], zoom_start=12)

for shape in shapes['data']:
    encoded_string = shape['attributes']['polyline']
    coordinates = PolylineCodec().decode(encoded_string)

    trail_coordinates = []
    trail_coordinates.append(coordinates)
    
    folium.PolyLine(trail_coordinates, tooltip="Coast").add_to(m)

m



# END SOLUTION
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_487be6759c00ade19fbbbc72fad226dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_487be6759c00ade19fbbbc72fad226dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_487be6759c00ade19fbbbc72fad226dd = L.map(
#                 &quot;map_487be6759c00ade19fbbbc72fad226dd&quot;,
#                 {
#                     center: [42.3601, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e701986149056188c7ede4283528aa6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e701986149056188c7ede4283528aa6e.addTo(map_487be6759c00ade19fbbbc72fad226dd);
#
#
#             var poly_line_da739c9e056f5485b8bf11ef9b8ad544 = L.polyline(
#                 [[[42.37411, -71.11907], [42.37426, -71.11901], [42.37442, -71.11897], [42.37464, -71.11895], [42.37486, -71.11894], [42.375, -71.11894], [42.37515, -71.11896], [42.37526, -71.11896], [42.37568, -71.11901], [42.37588, -71.11904], [42.376, -71.11907], [42.37608, -71.1191], [42.37614, -71.11916], [42.37621, -71.11925], [42.37628, -71.1194], [42.37634, -71.11948], [42.37637, -71.11939], [42.37638, -71.11931], [42.37649, -71.11948], [42.37667, -71.11965], [42.3767, -71.11967], [42.37672, -71.11968], [42.37686, -71.11977], [42.37753, -71.12001], [42.37773, -71.12006], [42.3778, -71.12007], [42.3778, -71.12007], [42.37794, -71.12008], [42.37844, -71.12004], [42.37892, -71.11998], [42.37947, -71.11993], [42.37972, -71.1199], [42.37997, -71.11986], [42.38042, -71.11982], [42.38082, -71.11978], [42.38164, -71.11969], [42.38164, -71.11969], [42.38172, -71.11968], [42.38257, -71.11959], [42.38377, -71.11946], [42.38443, -71.11938], [42.38475, -71.11935], [42.38482, -71.11935], [42.3849, -71.11934], [42.3849, -71.11934], [42.38535, -71.11929], [42.3858, -71.11924], [42.38631, -71.11918], [42.38678, -71.11912], [42.3871, -71.1191], [42.38739, -71.11914], [42.38776, -71.11923], [42.38803, -71.11931], [42.38803, -71.11931], [42.38816, -71.11935], [42.38833, -71.11939], [42.38843, -71.11942], [42.38876, -71.11952], [42.38904, -71.11967], [42.38915, -71.11974], [42.38929, -71.11985], [42.38929, -71.11985], [42.38941, -71.11996], [42.38989, -71.12045], [42.39012, -71.12071], [42.39031, -71.12095], [42.39098, -71.11995], [42.39124, -71.11958], [42.39156, -71.11909], [42.39166, -71.11919], [42.3918, -71.11932], [42.3918, -71.11932], [42.39187, -71.11938], [42.39233, -71.11981], [42.39277, -71.12021], [42.39282, -71.12026], [42.39313, -71.12048], [42.39364, -71.12079], [42.39364, -71.12079], [42.3938, -71.12089], [42.39406, -71.12062], [42.39429, -71.1204], [42.39441, -71.12027], [42.39471, -71.11996], [42.39522, -71.11943], [42.39568, -71.12048], [42.39604, -71.12026], [42.39604, -71.12026], [42.39622, -71.12015], [42.39646, -71.12101], [42.39651, -71.12148], [42.3966, -71.1219], [42.3966, -71.1219], [42.39666, -71.12217], [42.39701, -71.12197], [42.39717, -71.12188], [42.39749, -71.12169], [42.39792, -71.12143], [42.39812, -71.12131], [42.39825, -71.12123], [42.39838, -71.12108], [42.39851, -71.1209], [42.3986, -71.12074], [42.3987, -71.12057], [42.39904, -71.11976], [42.39913, -71.11954], [42.39913, -71.11954], [42.39921, -71.11936], [42.39942, -71.11892], [42.39986, -71.11823], [42.40058, -71.11722], [42.40058, -71.11722], [42.40058, -71.11722], [42.40088, -71.11684], [42.40092, -71.11661], [42.40104, -71.11645], [42.40112, -71.1164], [42.4012, -71.11639], [42.40123, -71.11641], [42.40126, -71.11645], [42.40128, -71.1165], [42.4013, -71.11655], [42.40144, -71.11671], [42.40157, -71.11685], [42.40172, -71.11687], [42.40172, -71.11687], [42.40203, -71.11692], [42.40272, -71.117], [42.404, -71.1172], [42.40484, -71.11732], [42.40519, -71.11738], [42.40519, -71.11738], [42.40542, -71.11741], [42.40563, -71.11745], [42.40581, -71.11743], [42.40582, -71.11743], [42.40615, -71.11725], [42.40665, -71.11687], [42.40671, -71.11684], [42.40671, -71.11684], [42.40679, -71.11679], [42.40681, -71.11678], [42.407, -71.11674], [42.40717, -71.11679], [42.40763, -71.11712], [42.40804, -71.11743], [42.40841, -71.11773], [42.40872, -71.11801], [42.40879, -71.11807], [42.40879, -71.11807], [42.40905, -71.11832], [42.40934, -71.11863], [42.40964, -71.11897], [42.41022, -71.1197], [42.41057, -71.12024], [42.41092, -71.12082], [42.41128, -71.1214], [42.41148, -71.12169], [42.41148, -71.12169], [42.41154, -71.12178], [42.41198, -71.12148], [42.41209, -71.12141], [42.4124, -71.12121], [42.41256, -71.12109], [42.41297, -71.12084], [42.41308, -71.12077], [42.41308, -71.12077], [42.41349, -71.12049], [42.41411, -71.12008], [42.41427, -71.11997], [42.4142, -71.11978], [42.4142, -71.11978], [42.41399, -71.1192], [42.41388, -71.11898], [42.41337, -71.11767],  ...

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION
